# %%
from os import listdir
from os.path import isfile, join
import pandas as pd

# 파일이름으로 > gsc url생성 
#file_path = 'C:/Users/ghkdn/Jupyter/ESTSOFT/Google_Vision_AI/rounz_glass_image'
file_path = 'C:/Users/ghkdn/Jupyter/ESTSOFT/Google_Vision_AI/rounz_image'
files_name = [f for f in listdir(file_path) if isfile(join(file_path, f))]
gcs_url = ["gs://hwao-bucket/"+str(url) for url in files_name]
print(files_name)
# 제품 id는 딥아이에서 제공하는 것을 그대로 불러옴 (현재는 주어졌다고 가정하고 리스트 만듬) 
product_id = ['MB618F-00','RB3447V-2620','RB5154-2000','RB6369D-2509','BOSS1067_F-124','BEACH-B-S(48)','VPR54T-1BO-1O1']
# Out:
# ['제품리스트.xlsx']

# %%
data = pd.DataFrame()
data['image_url'] = gcs_url
data['item_id'] = 1
for i in range(len(data)):
    name = 'item'+ str(i)
    data['item_id'][i] = name
data['project_set_id'] = 'house_glass1'
# Out:
# C:\Users\ghkdn\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#  jpg 이미지 파일 경로 샘플 
#  출처: http://seorenn.blogspot.com/2012/12/python_23.html

file_path = 'C:/Users/ghkdn/Jupyter/ESTSOFT/Google_Vision_AI/rounz_image'
def allfiles(path):
    res = []

    for root, dirs, files in os.walk(path):
        rootpath = os.path.join(os.path.abspath(path), root)

        for file in files:
            filepath = os.path.join(rootpath, '.jpg')
            filepath = filepath.rstrip('\\.jpg') 
            res.append(filepath)

    return res
file_path = allfiles(file_path)
file_path = list(set(file_path ))
#files_name = [f for f in listdir(file_path) if isfile(join(file_path, f))]
#file_name
files_name = []

for i in file_path:
    temp_name = [f for f in listdir(i) if isfile(join(i, f))]
    files_name +=temp_name 
files_name
# Out:
# ['MALCOLM-A2_01.jpg',
#  'MALCOLM-A2_02.jpg',
#  'MALCOLM-A2_03.jpg',
#  'MALCOLM-A2_04.jpg',
#  'VPR51VVD-YEP-1O1_01.jpg',
#  'VPR51VVD-YEP-1O1_02.jpg',
#  'VPR51VVD-YEP-1O1_03.jpg',
#  'VPR51VVD-YEP-1O1_04.jpg',
#  'OO9290-59_01.jpg',
#  'OO9290-59_02.jpg',
#  'OO9290-59_03.jpg',
#  'OO9290-59_04.jpg',
#  'GG0593SK-003_01.jpg',
#  'GG0593SK-003_02.jpg',
#  'GG0593SK-003_03.jpg',
#  'GG0593SK-003_04.jpg',
#  'MONET-GU_01.jpg',
#  'MONET-GU_02.jpg',
#  'MONET-GU_03.jpg',
#  'MONET-GU_04.jpg',
#  'D1235-C02_01.JPG',
#  'D1235-C02_02.JPG',
#  'D1235-C02_03.JPG',
#  'D1235-C02_04.JPG',
#  '제품리스트.xlsx',
#  'VE2090-YET_01.jpg',
#  'VE2090-YET_02.jpg',
#  'VE2090-YET_03.jpg',
#  'VE2090-YET_04.jpg',
#  'HORIZON763-03_01.jpg',
#  'HORIZON763-03_02.jpg',
#  'HORIZON763-03_03.jpg',
#  'HORIZON763-03_04.jpg',
#  'OO4139-01_01.jpg',
#  'OO4139-01_02.jpg',
#  'OO4139-01_03.jpg',
#  'OO4139-01_04.jpg',
#  'KZ40094F-14A_01.jpg',
#  'KZ40094F-14A_02.jpg',
#  'KZ40094F-14A_03.jpg',
# ...

# %%
data['product_id'] =1
for i in range(len(data['image_url'])):
    temp_url = data['image_url'][i]
    for j in product_id:
        temp_index = temp_url.find(j)
        if temp_index != -1:
            data['product_id'][i] = j
data['product_category'] = 'general-v1'   
data['product_display_name'] = 'glass_display'
data['labels'] = "category=glass"

data['bounding-poly'] = ","
data.to_csv("gsc_csv_v4.csv",index =False,header=False)
# index와 columns(header) 빼고 추출하기
# Out:
# C:\Users\ghkdn\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
data
# Out:
#                                        image_url item_id project_set_id  \
# 0          gs://hwao-bucket/BEACH-B-S(48)_01.jpg   item0   house_glass1
# 1          gs://hwao-bucket/BEACH-B-S(48)_02.jpg   item1   house_glass1
# 2          gs://hwao-bucket/BEACH-B-S(48)_03.jpg   item2   house_glass1
# 3          gs://hwao-bucket/BEACH-B-S(48)_04.jpg   item3   house_glass1
# 4         gs://hwao-bucket/BOSS1067_F-124_01.jpg   item4   house_glass1
# 5         gs://hwao-bucket/BOSS1067_F-124_02.jpg   item5   house_glass1
# 6         gs://hwao-bucket/BOSS1067_F-124_03.jpg   item6   house_glass1
# 7         gs://hwao-bucket/BOSS1067_F-124_04.jpg   item7   house_glass1
# 8             gs://hwao-bucket/MB618F-001_01.jpg   item8   house_glass1
# 9             gs://hwao-bucket/MB618F-001_02.jpg   item9   house_glass1
# 10            gs://hwao-bucket/MB618F-001_03.jpg  item10   house_glass1
# 11            gs://hwao-bucket/MB618F-001_04.jpg  item11   house_glass1
# ...
